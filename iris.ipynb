# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# Load the Iris dataset
iris = sns.load_dataset('iris')

# %%
# Exploratory Data Analysis (EDA)
print("Exploratory Data Analysis (EDA):")
print(iris.head())
print(iris.info())
print(iris.describe())
# Out:
# Exploratory Data Analysis (EDA):
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Data Preprocessing
print("\nData Preprocessing:")
print("Checking for missing values:")
print(iris.isnull().sum())
# Out:
# Data Preprocessing:
# Checking for missing values:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Visualization
print("\nVisualization:")
# Bar Plot
sns.barplot(x='species', y='sepal_length', data=iris)
plt.title("Mean Sepal Length by Species")
plt.show()
# Out:
# Visualization:

# %%
# Box Plot
sns.boxplot(x='species', y='petal_length', data=iris)
plt.title("Petal Length Distribution by Species")
plt.show()

# %%
# Data Analytics
print("Data Analytics:")
print(data.describe())

# Data Preprocessing
print("\nData Preprocessing:")
print("Check for missing values:")
print(data.isnull().sum())

# Data Engineering
print("\nData Engineering:")
# Add a new feature 'Sepal_Ratio'
data['Sepal_Ratio'] = data['Sepal_Length'] / data['Sepal_Width']
# Out:
# Data Analytics:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count   1000.000000  1000.000000   1000.000000  1000.000000
# mean       5.851599     3.078334      3.769918     1.185773
# std        0.587530     0.398982      1.671872     0.780621
# min        3.895240     1.873845     -1.373171    -1.026381
# 25%        5.451446     2.807503      2.658401     0.639560
# 50%        5.855180     3.075231      3.759574     1.200140
# 75%        6.228766     3.341553      4.883556     1.706879
# max        8.151639     4.327243     10.434604     3.664751
#
# Data Preprocessing:
# Check for missing values:
# Sepal_Length    0
# Sepal_Width     0
# Petal_Length    0
# Petal_Width     0
# Species         0
# dtype: int64
#
# Data Engineering:

# %%
# Visualization
print("\nVisualization:")
# Bar plot
sns.barplot(x='Species', y='Sepal_Length', data=data, ci=None)
plt.title("Mean Sepal Length by Species")
plt.show()
# Out:
# Visualization:

# %%
# Violin Plot
sns.violinplot(x='species', y='sepal_width', data=iris)
plt.title("Sepal Width Distribution by Species")
plt.show()

# %%
# Distplot
sns.distplot(iris['petal_width'])
plt.title("Distribution of Petal Width")
plt.show()
# Out:
# /home/mayank/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Count Plot
sns.countplot(x='species', data=iris)
plt.title("Species Count")
plt.show()

# %%
# Pair Plot
sns.pairplot(data=iris, hue='species')
plt.title("Pair Plot of Iris Dataset")
plt.show()

# %%
# Heatmap
correlation_matrix = iris.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
# Line Plot
sns.lineplot(data=iris[['sepal_length', 'sepal_width']])
plt.title("Line Plot of Sepal Length and Sepal Width")
plt.show()

# %%
# Scatter Plot
sns.scatterplot(x='petal_length', y='petal_width', data=iris, hue='species')
plt.title("Scatter Plot of Petal Length vs Petal Width")
plt.show()

# %%
# Scatter plot
sns.scatterplot(x='Sepal_Length', y='Petal_Width', data=data, hue='Species')
plt.title("Scatter Plot of Sepal Length vs Petal Width")
plt.show()

# %%
# Regplot
sns.regplot(x='sepal_length', y='sepal_width', data=iris)
plt.title("Regression Plot of Sepal Length vs Sepal Width")
plt.show()

# %%
# Modeling
print("\nModeling:")
# Prepare the data
X = iris.drop('species', axis=1)
y = iris['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# KNN Model
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
print("\nKNN Classification Report:")
print(classification_report(y_test, knn.predict(X_test)))
# Out:
# Modeling:
#
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# Random Forest Classifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
print("\nRandom Forest Classification Report:")
print(classification_report(y_test, rf.predict(X_test)))
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# Support Vector Machine
svm = SVC()
svm.fit(X_train, y_train)
print("\nSVM Classification Report:")
print(classification_report(y_test, svm.predict(X_test)))
# Out:
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
